# %%
import pandas as pd

# Assuming your data is stored in a DataFrame called 'df'
file_path = "/home/achu/Desktop/GitHubECGWork/Implementation_of_paper/ECG-Analysis/ECG-Analysis/exams.csv"
df = pd.read_csv(file_path)
# Select the columns of interest for conditions
conditions_columns = ['1dAVb', 'RBBB', 'LBBB', 'SB', 'ST', 'AF', 'normal_ecg']
# Create a new column 'num_diseases' representing the total number of diseases for each patient
df['num_diseases'] = df[conditions_columns].sum(axis=1)
# Initialize a dictionary to store the counts of each combination
combination_counts = {}
# Iterate over unique combinations of diseases
for combination in df[conditions_columns].apply(tuple, axis=1).unique():
    count = (df[conditions_columns].apply(tuple, axis=1) == combination).sum()
    combination_counts[combination] = count
# Iterate over unique combinations of diseases
for combination, count in combination_counts.items():
    # Filter the diseases that are True in the combination
    true_diseases = [condition for condition, is_true in zip(conditions_columns, combination) if is_true]
    # Display the counts for each combination
    print(f"Combination {', '.join(true_diseases)}: {count} patients")
# Out:
# Combination normal_ecg: 134657 patients
# Combination : 173347 patients
# Combination AF: 5609 patients
# Combination SB: 4890 patients
# Combination RBBB: 7685 patients
# Combination 1dAVb: 4196 patients
# Combination ST: 6976 patients
# Combination RBBB, AF: 661 patients
# Combination LBBB: 4748 patients
# Combination 1dAVb, LBBB: 407 patients
# Combination LBBB, AF: 423 patients
# Combination 1dAVb, RBBB: 639 patients
# Combination RBBB, SB: 293 patients
# Combination LBBB, ST: 217 patients
# Combination 1dAVb, SB: 227 patients
# Combination LBBB, SB: 78 patients
# Combination ST, AF: 143 patients
# Combination RBBB, LBBB: 73 patients
# Combination RBBB, ST: 182 patients
# Combination 1dAVb, ST: 28 patients
# Combination SB, AF: 19 patients
# Combination 1dAVb, AF: 96 patients
# Combination RBBB, LBBB, AF: 10 patients
# Combination 1dAVb, RBBB, SB: 53 patients
# Combination 1dAVb, LBBB, AF: 14 patients
# Combination RBBB, ST, AF: 22 patients
# Combination RBBB, LBBB, SB: 15 patients
# Combination 1dAVb, RBBB, LBBB: 7 patients
# Combination RBBB, LBBB, ST: 4 patients
# Combination 1dAVb, LBBB, ST: 3 patients
# Combination 1dAVb, RBBB, AF: 18 patients
# Combination 1dAVb, LBBB, SB: 17 patients
# Combination RBBB, SB, AF: 4 patients
# Combination LBBB, ST, AF: 5 patients
# Combination 1dAVb, SB, AF: 4 patients
# Combination 1dAVb, RBBB, LBBB, SB: 3 patients
# Combination 1dAVb, ST, AF: 2 patients
# Combination 1dAVb, RBBB, SB, AF: 1 patients
# Combination LBBB, SB, AF: 1 patients
# Combination 1dAVb, RBBB, ST: 1 patients
# Combination RBBB, LBBB, ST, AF: 1 patients

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming combination_counts is a dictionary with combination counts

# Function to categorize combinations based on the number of "True" values
def categorize_combinations(combination):
    num_true_values = sum(combination)
    if num_true_values == 0:
        return 'No True'
    elif num_true_values == 1:
        return '1 True'
    else:
        return 'Others'

# Categorize combinations and count patients
categorized_counts = {'Not Classified': 0, '1 True': 0, 'Other Combination': 0}
for combination, count in combination_counts.items():
    category = categorize_combinations(combination)
    categorized_counts[category] += count

# Pie chart for categorizations
labels = list(categorized_counts.keys())
sizes = list(categorized_counts.values())

# Pie chart
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("viridis", n_colors=len(labels)))
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
ax.set_title('Combinations with 1 True and No True')

plt.show()
